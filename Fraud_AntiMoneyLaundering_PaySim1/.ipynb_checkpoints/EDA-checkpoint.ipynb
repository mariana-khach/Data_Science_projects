# %% [markdown]
# # Fraud Detection

# %% [markdown]
# We use synthetic dataset generated using the simulator called PaySim for financial logs from a mobile money service.
#
# Data file location in kaggle
# https://www.kaggle.com/datasets/ealaxi/paysim1?resource=download
#
# PhD thesis that describes data simulations
# http://urn.kb.se/resolve?urn=urn:nbn:se:bth-12932
#
# Paper describing PaySim
# E. A. Lopez-Rojas , A. Elmir, and S. Axelsson. "PaySim: A financial mobile money simulator for fraud detection". In: The 28th European Modeling and Simulation Symposium-EMSS, Larnaca, Cyprus. 2016

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv("data/raw/PS_20174392719_1491204439457_log.csv")

# %%
df.info(verbose=True, show_counts=True)
#There don't seem to be any missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   step            6362620 non-null  int64
#  1   type            6362620 non-null  object
#  2   amount          6362620 non-null  float64
#  3   nameOrig        6362620 non-null  object
#  4   oldbalanceOrg   6362620 non-null  float64
#  5   newbalanceOrig  6362620 non-null  float64
#  6   nameDest        6362620 non-null  object
#  7   oldbalanceDest  6362620 non-null  float64
#  8   newbalanceDest  6362620 non-null  float64
#  9   isFraud         6362620 non-null  int64
#  10  isFlaggedFraud  6362620 non-null  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %% [markdown]
# step - maps a unit of time in the real world. In this case 1 step is 1 hour of time. Total steps 744 (30 days simulation).
#
# type - CASH-IN, CASH-OUT, DEBIT, PAYMENT and TRANSFER.
#
# amount -
# amount of the transaction in local currency.
#
# nameOrig - customer who started the transaction
#
# oldbalanceOrg - initial balance before the transaction
#
# newbalanceOrig - new balance after the transaction.
#
# nameDest - customer who is the recipient of the transaction
#
# oldbalanceDest - initial balance recipient before the transaction. Note that there is not information for customers that start with M (Merchants).
#
# newbalanceDest - new balance recipient after the transaction. Note that there is not information for customers that start with M (Merchants).
#
# isFraud - This is the transactions made by the fraudulent agents inside the simulation. In this specific dataset the fraudulent behavior of the agents aims to profit by taking control or customers accounts and try to empty the funds by transferring to another account and then cashing out of the system.
#
# isFlaggedFraud - The business model aims to control massive transfers from one account to another and flags illegal attempts. An illegal attempt in this dataset is an attempt to transfer more than 200.000 in a single transaction.
#
# NOTE: Transactions which are detected as fraud are cancelled, so for fraud detection these columns (oldbalanceOrg, newbalanceOrig, oldbalanceDest, newbalanceDest ) must not be used.

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
len(df)
# Out:
# 6362620

# %%
df.describe()
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  6.362620e+06  6.362620e+06   6.362620e+06    6.362620e+06
# mean   2.433972e+02  1.798619e+05   8.338831e+05    8.551137e+05
# std    1.423320e+02  6.038582e+05   2.888243e+06    2.924049e+06
# min    1.000000e+00  0.000000e+00   0.000000e+00    0.000000e+00
# 25%    1.560000e+02  1.338957e+04   0.000000e+00    0.000000e+00
# 50%    2.390000e+02  7.487194e+04   1.420800e+04    0.000000e+00
# 75%    3.350000e+02  2.087215e+05   1.073152e+05    1.442584e+05
# max    7.430000e+02  9.244552e+07   5.958504e+07    4.958504e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    6.362620e+06    6.362620e+06  6.362620e+06    6.362620e+06
# mean     1.100702e+06    1.224996e+06  1.290820e-03    2.514687e-06
# std      3.399180e+06    3.674129e+06  3.590480e-02    1.585775e-03
# min      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# ...

# %%
df["step"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["nameOrig"].nunique()
# Out:
# 6353307

# %%
df["nameDest"].nunique()
# Out:
# 2722362

# %%
df[df["nameOrig"]==df["nameDest"]]
# Out:
# Empty DataFrame
# Columns: [step, type, amount, nameOrig, oldbalanceOrg, newbalanceOrig, nameDest, oldbalanceDest, newbalanceDest, isFraud, isFlaggedFraud]
# Index: []

# %%
#plt.figure(figize=(8,6),dpi=150)
sns.scatterplot(data=df, x="step",y="amount")
# Out:
# <Axes: xlabel='step', ylabel='amount'>

# %%
# drop nameOrig, nameDest
#use StringIndexer and OneHotEncoder for "type" column

# %%
#total number of rows is 6362620

# %% [markdown]
# #Engineer useful financial features inspired by PaySim analysis and AML patterns.
# #based on https://scispace.com/pdf/analysis-of-fraud-controls-using-the-paysim-financial-4dvauv8xq7.pdf
#
# Examples:
#
# Net change in balances:
# deltaOrig = oldbalanceOrg - newbalanceOrg
#
# deltaDest = newbalanceDest - oldbalanceDest
#
# Inconsistency flags:
#
# flagOrigMismatch = (oldbalanceOrg + amount - newbalanceOrg != 0)
#
# flagDestMismatch = (oldbalanceDest + amount - newbalanceDest != 0

# %%
1. Need also to scale the data
2. Customized the train–validation–test split to respect the temporal nature of the data. Since many of our engineered features relied on 30‑day rolling windows
3. Use cross validation

# %% [markdown]
# (A) Imbalanced fraud classification
#
# Use ideas from Dal Pozzolo et al. “Calibrating Probability with Undersampling for Unbalanced Classification” and related credit-card fraud work.
# Slides https://pdfs.semanticscholar.org/e36b/b7fbe1b4f7c521608e93a2215e2062dae5b1.pdf?utm_source=chatgpt.com
#
#
# From these papers you’ll borrow:
# Random undersampling of the majority class
# Cost-sensitive learning / class weights
# PR-AUC as main metric (better for extreme imbalance than ROC-AUC)
#
#
# Engineer useful financial features inspired by PaySim analysis and AML patterns
# https://scispace.com/pdf/analysis-of-fraud-controls-using-the-paysim-financial-4dvauv8xq7.pdf
#
#
# From AML on Bitcoin / Elliptic datasets:
#
# RF and tree ensembles work very well for AML classification.
# Based on the following paper https://arxiv.org/pdf/1908.02591
# Graph / network patterns matter (Graph Neural Network), but you can start with tabular + engineered feature
#
# So your main PySpark ML models:
# Baseline: Logistic Regression (with class weights)
# Main model: Random Forest Classifier
# Optional: Gradient-Boosted Trees (GBTClassifier)
#
# Then try  Temporal Graph Neural Network model from Erdos

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("PaySimFraud").getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# PySparkRuntimeError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 spark = SparkSession.builder.appName("PaySimFraud").getOrCreate()
#
# File ~\anaconda3\envs\pyspark_env\Lib\site-packages\pyspark\sql\session.py:556, in SparkSession.Builder.getOrCreate(self)
#     554     sparkConf.set(key, value)
#     555 # This SparkContext may be an existing one.
# --> 556 sc = SparkContext.getOrCreate(sparkConf)
#     557 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     558 # by all sessions.
#     559 session = SparkSession(sc, options=self._options)
#
# File ~\anaconda3\envs\pyspark_env\Lib\site-packages\pyspark\core\context.py:523, in SparkContext.getOrCreate(cls, conf)
#     521 with SparkContext._lock:
#     522     if SparkContext._active_spark_context is None:
# --> 523         SparkContext(conf=conf or SparkConf())
# ...

# %%
data_path = "data/raw/PS_20174392719_1491204439457_log.csv"

df = spark.read.csv(data_path, header=True, inferSchema=True)
df.printSchema()
df.show(5)
df.groupBy("isFraud").count().show()
