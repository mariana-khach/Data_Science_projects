# %%
#In this project we use K means clustering for unsupervised learning for color quanization of an image

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg   #allows to convert image to numpy arrays
import pandas as pd

from sklearn.cluster import KMeans

# %%
image_arr_3d=mpimg.imread("sailboat.jfif")

# %%
h,w,c=image_arr_3d.shape            # this gives us the following parameters for image (Height,width,color)

# %%
plt.imshow(image_arr)

# %%
image_arr_2d=image_arr_3d.reshape(h*w,c)

# %%
KM=KMeans(n_clusters=3)
cluster_name=KM.fit_predict(image_arr_2d)
# Out:
# C:\Users\17573\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
cluster_name
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
cluster_name.shape
# Out:
# (50268,)

# %%
h*w
# Out:
# 50268

# %%
clust=KM.cluster_centers_.round(0).astype(int) #3 averaged out red green blue colors

# %%
trans_imag=clust[cluster_name]

# %%
trans_imag_3d=np.reshape(trans_imag,(h,w,c))

# %%
plt.imshow(trans_imag_3d)

# %%
#We can see that we are left with three colors in the picture, as we wanted
